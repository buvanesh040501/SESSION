# %% [markdown]
# #Workouts for the ML intro session

# %% [markdown]
# ##Complete all the cells and upload the note book to github
#
# **Kindly use your own explanations and examples. you refer the internet but try to explain things with your own words and examples**

# %% [markdown]
# 1.  Will machine overtake humans in near future ? if yes explain why ? if not explain what prevents machines to learn/perform at human level ?<br>
# Yes, robots will replace humans for many jobs, just as innovative farming. we call this machine learning, and still other times we call this robotics ,These two same concept.

# %% [markdown]
# 2. What recent development you think is very important or inspiring in machine learning/AI field ? just few words on any one or two<br>
# Machines learn and provide intelligent insights through a sophisticated use of learning algorithms. To provide business value, the machine is trained to learn patterns from data and then can proceed autonomously on new and changing data

# %% [markdown]
# 3. What is the differnce between regular programming or machine learning ?<br>
# Regular programming is a manual process.It means programmer creates the program. Without anyone programming the logic, one has to manually formulate the code rules. But machine learning algorithm automatically formulates the rules from the data.

# %% [markdown]
# 4. What is model is machine learning ?
#
#  Supervised and unsupervised machine learning, the model describes the signal in the noise or the pattern detected from the training data. Reinforcement learning, the model describes the best possible course of action given a specific situation.

# %% [markdown]
# 5. how/where machine learning stores its learning ? <br>
# No, in ML don't store input/output values, but internal state of the algorithm.example a neural network used for face recognition and such, has a number of variables internally that change as the model learns. These are the variables you would need to store

# %% [markdown]
# 6. What is training ?<br>
# Training a model simply means learning good values for all the weights and the bias from labeled examples.

# %% [markdown]
# 7. what is reinforcement learning ?<br>
# Reinforcement Learning is a feedback-based Machine learning technique in which an agent learns to behave in an environment by performing the actions

# %% [markdown]
# 8. Give use cases for classification, clustering and regression ?<br>
# Regression and Classification are types of supervised learning algorithms while Clustering is a type of unsupervised algorithm. When the output variable is continuous, then it is a regression problem whereas when it contains discrete values, it is a classification problem

# %% [markdown]
# 9. What is dimension ? will more dimension be helpful to improve a machine learning model ? <br>
# The number of input variables or features for a dataset is referred to as its dimensionality.More input features often make a predictive modeling task more challenging to model, more generally referred to as the curse of dimensionality.

# %% [markdown]
# 10. what is hypothetical space ? explain with an example
# Hypothesis space is the set of all the possible legal hypothesis. This is the set from which the machine learning algorithm would determine the best possible which would best describe the target function or the outputs.Example,![image.png](data:image/png;base64,...)
